# %% [markdown]
# # Supplementary Notebook 4: Select Major ABR genes
# ## Paper: Novel Approach for Microbiome Analysis Using Bacterial Replication Rates and Causal Inference to Determine Resistome Potential
# ### Vitalii Stebliankin, Musfiqur Sazal, Camilo Valdes, Kalai Mathee, and GiriNarasimhan
#
# #### Dataset: Gibson et al. (BioProject ID: PRJNA301903)
#
# In this notebook we will select ABR genes that present in at least 5% of the study samples

# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
import os

# amr = "A-out/ptr_amr.csv"
# major_file="analysis-out/1-FilteringPTR/PTR_species_filtered_metadata_major.csv"

amr = "A-out/ptr_amr_RPKM.csv"
major_file="analysis-out/1-FilteringPTR/PTR_species_filtered_metadata_major.csv"

out_dir="analysis-out/4-Select_major_ABR"
if not os.path.exists(out_dir):
    os.mkdir(out_dir)
    
out_file = out_dir+"/PTR_species_filtered_metadata_major_AMR.csv"


clinical_vars = ["Day_of_Life", "PostMenst_Age", "Gestational_Age",
                       "Birthweight", "Gentamicin", "Cefazolin","Ampicillin", "Trimethoprim.Sulfamathoxazole", "Meropenem",
                       "Vancomycin", "Ticarcillin.Clavulanate", "Clindamycin", "Cefotaxime", "Total_abx", "r_Gentamicin",
                       "r_Meropenem", "r_Ticarcillin.Clavulanate", "r_Vancomycin", "r_Ampicillin",
                       "r_Cefotaxime","r_TOTAL","Human_Milk","Maternal_Milk", "Donor_Milk", "Formula","Fortification","Vitamin_A",
                       "Caffeine","Iron","Furosemide_Lasix","m_ampicillin","m_ceftriaxone","m_azithromycin",
                       "m_amoxicillin", "m_cefazolin","m_erythromycin","m_gentamicin","m_penicillin","m_vancomycin",
                       "m_clindamycin","m_cefotaxime", "dur_membrane_rupture","Total.Antibiotic.Days", "Cohort", "CRIB.II.Score"]

threshold = 20
#method="top_largest"
method= "top_present"

df = pd.read_csv(amr)
amr_dict={"amr":[],"value":[], "nvalues":[]}

for col in df.columns:
    if "gb|" in col:
        amr_dict["value"].append(df[col].mean())
        amr_dict["amr"].append(col)
        amr_dict["nvalues"].append(len(df[df[col]>0]))


# Threshold. Top 200
amr_sorted = sorted(amr_dict["value"])
amr_df = pd.DataFrame(amr_dict)
print(len(amr_df))

if method=="top_largest":
    # Top Top 10 %:
    top_200 = amr_sorted[-threshold]
    #top_ten = amr_df["value"].quantile(.80)
    amr_df = amr_df[amr_df["value"]>top_200]
    amr_list = list(amr_df["amr"])

if method=="top_present":
    amr_df = amr_df[amr_df["nvalues"]>threshold]
    amr_list = list(amr_df["amr"])

print(len(amr_df))

new_amr_df = df[["sample"]+amr_list]
new_amr_df.index = new_amr_df["sample"]
new_amr_df = new_amr_df.drop("sample", axis=1)
new_amr_df.rename(columns=lambda x: x.replace("\n","").split("|")[-2] + x.replace("\n","").split("|")[-1], inplace=True)

#new_amr_df["sample"] = new_amr_df.index
# Merge with major df:
major_df = pd.read_csv(major_file)

major_df = major_df.merge(new_amr_df, on="sample", how="left")
major_df = major_df.fillna(1)

cols_to_drop = ["Clindamycin","Cefotaxime"]
for col in cols_to_drop:
    major_df = major_df.drop(col, axis=1)

major_df = major_df.drop("sample", axis=1)
major_df = major_df.drop("Individual", axis=1)
major_df = major_df.drop("AveragePTR", axis=1)
#major_df = major_df.drop("Cohort", axis=1)
major_df = major_df.drop("Antibiotic_Treatment", axis=1)
major_df = major_df.drop("Trimethoprim-Sulfamathoxazole", axis=1)
major_df = major_df.drop("Antibiotic_Treatment_unfiltered", axis=1)



#major_df.to_csv(out_file, index=False)
#major_df.to_csv(out_file, index=False)
# Out:
# 975
# 479

# %%
# Plot ABR profile

amr_df = pd.read_csv(amr)
amr_cols = []
for col in amr_df.columns:
    if "ARO" in col:
        amr_cols.append(col)
        
amr_df.index = amr_df['Cohort']
amr_df = amr_df[amr_cols]
amr_df
# Out:
#             gb|AB008454|+|153-1290|ARO:3002493|SRT-1  \
# Cohort
# Control                                          0.0
# Antibiotic                                       0.0
# Antibiotic                                       0.0
# Antibiotic                                       0.0
# Antibiotic                                       0.0
# ...                                              ...
# Antibiotic                                       0.0
# Antibiotic                                       0.0
# Control                                          0.0
# Control                                          0.0
# Antibiotic                                       0.0
#
#             gb|AB013298.1|+|2295-3195|ARO:3000319|mphC  \
# Cohort
# Control                                       9.268764
# Antibiotic                                    7.080939
# Antibiotic                                    5.108332
# Antibiotic                                    0.000000
# Antibiotic                                    0.000000
# ...                                                ...
# Antibiotic                                    4.502611
# Antibiotic                                    0.000000
# Control                                       0.000000
# Control                                       0.000000
# Antibiotic                                    0.000000
#
#             gb|AB015853|+|1330-4471|ARO:3003033|mexY  \
# Cohort
# Control                                          0.0
# Antibiotic                                       0.0
# Antibiotic                                       0.0
# Antibiotic                                       0.0
# Antibiotic                                       0.0
# ...                                              ...
# Antibiotic                                       0.0
# Antibiotic                                       0.0
# Control                                          0.0
# Control                                          0.0
# Antibiotic                                       0.0
#
#             gb|AB015853|+|145-1315|ARO:3003034|mexX  \
# Cohort
# Control                                         0.0
# Antibiotic                                      0.0
# Antibiotic                                      0.0
# Antibiotic                                      0.0
# Antibiotic                                      0.0
# ...                                             ...
# Antibiotic                                      0.0
# Antibiotic                                      0.0
# Control                                         0.0
# Control                                         0.0
# Antibiotic                                      0.0
#
#             gb|AB023477|+|0-861|ARO:3001082|SHV-24  \
# Cohort
# Control                                        0.0
# Antibiotic                                     0.0
# Antibiotic                                     0.0
# Antibiotic                                     0.0
# Antibiotic                                     0.0
# ...                                            ...
# Antibiotic                                     0.0
# Antibiotic                                     0.0
# Control                                        0.0
# Control                                        0.0
# Antibiotic                                     0.0
#
#             gb|AB049569|+|0-861|ARO:3000958|TEM-91  \
# Cohort
# Control                                        0.0
# Antibiotic                                     0.0
# Antibiotic                                     0.0
# Antibiotic                                     0.0
# Antibiotic                                     0.0
# ...                                            ...
# Antibiotic                                     0.0
# Antibiotic                                     0.0
# Control                                        0.0
# Control                                        0.0
# Antibiotic                                     0.0
#
#             gb|AB089595|+|0-1206|ARO:3000166|tet(B)  \
# Cohort
# Control                                         0.0
# Antibiotic                                      0.0
# Antibiotic                                      0.0
# Antibiotic                                      0.0
# Antibiotic                                      0.0
# ...                                             ...
# Antibiotic                                      0.0
# Antibiotic                                      0.0
# Control                                         0.0
# Control                                         0.0
# Antibiotic                                      0.0
#
#             gb|AB091338|+|173-1355|ARO:3003551|emeA  \
# Cohort
# Control                                    6.360852
# Antibiotic                                 7.068502
# Antibiotic                                 0.000000
# Antibiotic                                 7.803591
# Antibiotic                                 7.573203
# ...                                             ...
# Antibiotic                                 0.000000
# Antibiotic                                 0.000000
# Control                                    3.577368
# Control                                    0.000000
# Antibiotic                                 4.112008
#
#             gb|AB204810|+|186-1533|ARO:3000753|abeM  \
# Cohort
# Control                                         0.0
# Antibiotic                                      0.0
# Antibiotic                                      0.0
# Antibiotic                                      0.0
# Antibiotic                                      0.0
# ...                                             ...
# Antibiotic                                      0.0
# Antibiotic                                      0.0
# Control                                         0.0
# Control                                         0.0
# Antibiotic                                      0.0
#
#             gb|AB205645|+|1012-1510|ARO:3002868|dfrG  ...  \
# Cohort                                                ...
# Control                                     0.000000  ...
# Antibiotic                                  0.000000  ...
# Antibiotic                                  5.012408  ...
# Antibiotic                                  0.000000  ...
# Antibiotic                                  0.000000  ...
# ...                                              ...  ...
# Antibiotic                                  0.000000  ...
# Antibiotic                                  0.000000  ...
# Control                                     0.000000  ...
# Control                                     0.000000  ...
# Antibiotic                                  0.000000  ...
#
#             gb|Y17581|+|78-936|ARO:3000891|TEM-20  \
# Cohort
# Control                                       0.0
# Antibiotic                                    0.0
# Antibiotic                                    0.0
# Antibiotic                                    0.0
# Antibiotic                                    0.0
# ...                                           ...
# Antibiotic                                    0.0
# Antibiotic                                    0.0
# Control                                       0.0
# Control                                       0.0
# Antibiotic                                    0.0
#
#             gb|Y17582|+|0-858|ARO:3000892|TEM-21  \
# Cohort
# Control                                      0.0
# Antibiotic                                   0.0
# Antibiotic                                   0.0
# Antibiotic                                   0.0
# Antibiotic                                   0.0
# ...                                          ...
# Antibiotic                                   0.0
# Antibiotic                                   0.0
# Control                                      0.0
# Control                                      0.0
# Antibiotic                                   0.0
#
#             gb|Y17583|+|213-1071|ARO:3000893|TEM-22  \
# Cohort
# Control                                         0.0
# Antibiotic                                      0.0
# Antibiotic                                      0.0
# Antibiotic                                      0.0
# Antibiotic                                      0.0
# ...                                             ...
# Antibiotic                                      0.0
# Antibiotic                                      0.0
# Control                                         0.0
# Control                                         0.0
# Antibiotic                                      0.0
#
#             gb|Y17584|+|0-858|ARO:3000899|TEM-29  \
# Cohort
# Control                                 0.000000
# Antibiotic                              0.000000
# Antibiotic                              0.000000
# Antibiotic                              0.000000
# Antibiotic                              0.265805
# ...                                          ...
# Antibiotic                              0.000000
# Antibiotic                              0.000000
# Control                                 0.000000
# Control                                 0.000000
# Antibiotic                              0.000000
#
#             gb|Y17714|+|146-1016|ARO:3002399|OXY-2-4  \
# Cohort
# Control                                          0.0
# Antibiotic                                       0.0
# Antibiotic                                       0.0
# Antibiotic                                       0.0
# Antibiotic                                       0.0
# ...                                              ...
# Antibiotic                                       0.0
# Antibiotic                                       0.0
# Control                                          0.0
# Control                                          0.0
# Antibiotic                                       0.0
#
#             gb|Y17715|+|146-1022|ARO:3002394|OXY-1-6  \
# Cohort
# Control                                          0.0
# Antibiotic                                       0.0
# Antibiotic                                       0.0
# Antibiotic                                       0.0
# Antibiotic                                       0.0
# ...                                              ...
# Antibiotic                                       0.0
# Antibiotic                                       0.0
# Control                                          0.0
# Control                                          0.0
# Antibiotic                                       0.0
#
#             gb|Z11877.1|+|485-818|ARO:3004039|Escherichia  \
# Cohort
# Control                                          0.000000
# Antibiotic                                       0.000000
# Antibiotic                                       0.000000
# Antibiotic                                       0.000000
# Antibiotic                                       0.000000
# ...                                                   ...
# Antibiotic                                       0.000000
# Antibiotic                                       0.000000
# Control                                          0.000000
# Control                                         17.323162
# Antibiotic                                       0.000000
#
#             gb|Z21523|+|0-1974|ARO:3000191|tetQ  \
# Cohort
# Control                                0.000000
# Antibiotic                             0.000000
# Antibiotic                             0.000000
# Antibiotic                             0.000000
# Antibiotic                             0.000000
# ...                                         ...
# Antibiotic                             0.000000
# Antibiotic                             0.000000
# Control                                0.000000
# Control                                4.063064
# Antibiotic                             0.000000
#
#             gb|Z30177|+|348-1224|ARO:3002389|OXY-1-1  \
# Cohort
# Control                                     0.000000
# Antibiotic                                  2.235241
# Antibiotic                                  0.000000
# Antibiotic                                  0.000000
# Antibiotic                                  0.000000
# ...                                              ...
# Antibiotic                                  0.000000
# Antibiotic                                  0.000000
# Control                                     0.000000
# Control                                     0.000000
# Antibiotic                                  0.000000
#
#             gb|Z49084|+|311-1184|ARO:3002402|OXY-2-7
# Cohort
# Control                                          0.0
# Antibiotic                                       0.0
# Antibiotic                                       0.0
# Antibiotic                                       0.0
# Antibiotic                                       0.0
# ...                                              ...
# Antibiotic                                       0.0
# Antibiotic                                       0.0
# Control                                          0.0
# Control                                          0.0
# Antibiotic                                       0.0
#
# [393 rows x 975 columns]

# %%
# check significance;
from scipy import stats
amr_df_tmp = amr_df.copy()
amr_df_tmp['cohort'] = amr_df_tmp.index

control_df = amr_df_tmp[amr_df_tmp['cohort']=='Control']
ab_df = amr_df_tmp[amr_df_tmp['cohort']=='Antibiotic']

cc_group = []
ac_group = []

for amr in amr_cols:
    U, p = stats.mannwhitneyu(control_df[amr], ab_df[amr])
    if p<0.05:
        if control_df[amr].mean()>ab_df[amr].mean():
            cc_group.append(amr)
        else:
            ac_group.append(amr)
print("{} genes are associated with CC".format(len(cc_group)))
print("{} genes are associated with AC".format(len(ac_group)))
# Out:
# 108 genes are associated with CC
# 337 genes are associated with AC

# %%
amr_df
# Out:
#             gb|AB008454|+|153-1290|ARO:3002493|SRT-1  \
# Cohort
# Control                                          0.0
# Antibiotic                                       0.0
# Antibiotic                                       0.0
# Antibiotic                                       0.0
# Antibiotic                                       0.0
# ...                                              ...
# Antibiotic                                       0.0
# Antibiotic                                       0.0
# Control                                          0.0
# Control                                          0.0
# Antibiotic                                       0.0
#
#             gb|AB013298.1|+|2295-3195|ARO:3000319|mphC  \
# Cohort
# Control                                       9.268764
# Antibiotic                                    7.080939
# Antibiotic                                    5.108332
# Antibiotic                                    0.000000
# Antibiotic                                    0.000000
# ...                                                ...
# Antibiotic                                    4.502611
# Antibiotic                                    0.000000
# Control                                       0.000000
# Control                                       0.000000
# Antibiotic                                    0.000000
#
#             gb|AB015853|+|1330-4471|ARO:3003033|mexY  \
# Cohort
# Control                                          0.0
# Antibiotic                                       0.0
# Antibiotic                                       0.0
# Antibiotic                                       0.0
# Antibiotic                                       0.0
# ...                                              ...
# Antibiotic                                       0.0
# Antibiotic                                       0.0
# Control                                          0.0
# Control                                          0.0
# Antibiotic                                       0.0
#
#             gb|AB015853|+|145-1315|ARO:3003034|mexX  \
# Cohort
# Control                                         0.0
# Antibiotic                                      0.0
# Antibiotic                                      0.0
# Antibiotic                                      0.0
# Antibiotic                                      0.0
# ...                                             ...
# Antibiotic                                      0.0
# Antibiotic                                      0.0
# Control                                         0.0
# Control                                         0.0
# Antibiotic                                      0.0
#
#             gb|AB023477|+|0-861|ARO:3001082|SHV-24  \
# Cohort
# Control                                        0.0
# Antibiotic                                     0.0
# Antibiotic                                     0.0
# Antibiotic                                     0.0
# Antibiotic                                     0.0
# ...                                            ...
# Antibiotic                                     0.0
# Antibiotic                                     0.0
# Control                                        0.0
# Control                                        0.0
# Antibiotic                                     0.0
#
#             gb|AB049569|+|0-861|ARO:3000958|TEM-91  \
# Cohort
# Control                                        0.0
# Antibiotic                                     0.0
# Antibiotic                                     0.0
# Antibiotic                                     0.0
# Antibiotic                                     0.0
# ...                                            ...
# Antibiotic                                     0.0
# Antibiotic                                     0.0
# Control                                        0.0
# Control                                        0.0
# Antibiotic                                     0.0
#
#             gb|AB089595|+|0-1206|ARO:3000166|tet(B)  \
# Cohort
# Control                                         0.0
# Antibiotic                                      0.0
# Antibiotic                                      0.0
# Antibiotic                                      0.0
# Antibiotic                                      0.0
# ...                                             ...
# Antibiotic                                      0.0
# Antibiotic                                      0.0
# Control                                         0.0
# Control                                         0.0
# Antibiotic                                      0.0
#
#             gb|AB091338|+|173-1355|ARO:3003551|emeA  \
# Cohort
# Control                                    6.360852
# Antibiotic                                 7.068502
# Antibiotic                                 0.000000
# Antibiotic                                 7.803591
# Antibiotic                                 7.573203
# ...                                             ...
# Antibiotic                                 0.000000
# Antibiotic                                 0.000000
# Control                                    3.577368
# Control                                    0.000000
# Antibiotic                                 4.112008
#
#             gb|AB204810|+|186-1533|ARO:3000753|abeM  \
# Cohort
# Control                                         0.0
# Antibiotic                                      0.0
# Antibiotic                                      0.0
# Antibiotic                                      0.0
# Antibiotic                                      0.0
# ...                                             ...
# Antibiotic                                      0.0
# Antibiotic                                      0.0
# Control                                         0.0
# Control                                         0.0
# Antibiotic                                      0.0
#
#             gb|AB205645|+|1012-1510|ARO:3002868|dfrG  ...  \
# Cohort                                                ...
# Control                                     0.000000  ...
# Antibiotic                                  0.000000  ...
# Antibiotic                                  5.012408  ...
# Antibiotic                                  0.000000  ...
# Antibiotic                                  0.000000  ...
# ...                                              ...  ...
# Antibiotic                                  0.000000  ...
# Antibiotic                                  0.000000  ...
# Control                                     0.000000  ...
# Control                                     0.000000  ...
# Antibiotic                                  0.000000  ...
#
#             gb|Y17581|+|78-936|ARO:3000891|TEM-20  \
# Cohort
# Control                                       0.0
# Antibiotic                                    0.0
# Antibiotic                                    0.0
# Antibiotic                                    0.0
# Antibiotic                                    0.0
# ...                                           ...
# Antibiotic                                    0.0
# Antibiotic                                    0.0
# Control                                       0.0
# Control                                       0.0
# Antibiotic                                    0.0
#
#             gb|Y17582|+|0-858|ARO:3000892|TEM-21  \
# Cohort
# Control                                      0.0
# Antibiotic                                   0.0
# Antibiotic                                   0.0
# Antibiotic                                   0.0
# Antibiotic                                   0.0
# ...                                          ...
# Antibiotic                                   0.0
# Antibiotic                                   0.0
# Control                                      0.0
# Control                                      0.0
# Antibiotic                                   0.0
#
#             gb|Y17583|+|213-1071|ARO:3000893|TEM-22  \
# Cohort
# Control                                         0.0
# Antibiotic                                      0.0
# Antibiotic                                      0.0
# Antibiotic                                      0.0
# Antibiotic                                      0.0
# ...                                             ...
# Antibiotic                                      0.0
# Antibiotic                                      0.0
# Control                                         0.0
# Control                                         0.0
# Antibiotic                                      0.0
#
#             gb|Y17584|+|0-858|ARO:3000899|TEM-29  \
# Cohort
# Control                                 0.000000
# Antibiotic                              0.000000
# Antibiotic                              0.000000
# Antibiotic                              0.000000
# Antibiotic                              0.265805
# ...                                          ...
# Antibiotic                              0.000000
# Antibiotic                              0.000000
# Control                                 0.000000
# Control                                 0.000000
# Antibiotic                              0.000000
#
#             gb|Y17714|+|146-1016|ARO:3002399|OXY-2-4  \
# Cohort
# Control                                          0.0
# Antibiotic                                       0.0
# Antibiotic                                       0.0
# Antibiotic                                       0.0
# Antibiotic                                       0.0
# ...                                              ...
# Antibiotic                                       0.0
# Antibiotic                                       0.0
# Control                                          0.0
# Control                                          0.0
# Antibiotic                                       0.0
#
#             gb|Y17715|+|146-1022|ARO:3002394|OXY-1-6  \
# Cohort
# Control                                          0.0
# Antibiotic                                       0.0
# Antibiotic                                       0.0
# Antibiotic                                       0.0
# Antibiotic                                       0.0
# ...                                              ...
# Antibiotic                                       0.0
# Antibiotic                                       0.0
# Control                                          0.0
# Control                                          0.0
# Antibiotic                                       0.0
#
#             gb|Z11877.1|+|485-818|ARO:3004039|Escherichia  \
# Cohort
# Control                                          0.000000
# Antibiotic                                       0.000000
# Antibiotic                                       0.000000
# Antibiotic                                       0.000000
# Antibiotic                                       0.000000
# ...                                                   ...
# Antibiotic                                       0.000000
# Antibiotic                                       0.000000
# Control                                          0.000000
# Control                                         17.323162
# Antibiotic                                       0.000000
#
#             gb|Z21523|+|0-1974|ARO:3000191|tetQ  \
# Cohort
# Control                                0.000000
# Antibiotic                             0.000000
# Antibiotic                             0.000000
# Antibiotic                             0.000000
# Antibiotic                             0.000000
# ...                                         ...
# Antibiotic                             0.000000
# Antibiotic                             0.000000
# Control                                0.000000
# Control                                4.063064
# Antibiotic                             0.000000
#
#             gb|Z30177|+|348-1224|ARO:3002389|OXY-1-1  \
# Cohort
# Control                                     0.000000
# Antibiotic                                  2.235241
# Antibiotic                                  0.000000
# Antibiotic                                  0.000000
# Antibiotic                                  0.000000
# ...                                              ...
# Antibiotic                                  0.000000
# Antibiotic                                  0.000000
# Control                                     0.000000
# Control                                     0.000000
# Antibiotic                                  0.000000
#
#             gb|Z49084|+|311-1184|ARO:3002402|OXY-2-7
# Cohort
# Control                                          0.0
# Antibiotic                                       0.0
# Antibiotic                                       0.0
# Antibiotic                                       0.0
# Antibiotic                                       0.0
# ...                                              ...
# Antibiotic                                       0.0
# Antibiotic                                       0.0
# Control                                          0.0
# Control                                          0.0
# Antibiotic                                       0.0
#
# [393 rows x 975 columns]

# %%
amr_df = amr_df.T

amr_aro_df = amr_df
amr_aro_df['ARO Accession'] = amr_df.index
amr_aro_df['ARO Accession'] = amr_df['ARO Accession'].apply(lambda x: x.split('|')[-2])
amr_aro_df = amr_aro_df[['ARO Accession']]

amr_df
# Merge ARO accession with gene family

aro_index="analysis-out/4-Select_major_ABR/aro_index.tsv"
aro_df = pd.read_csv(aro_index, sep='\t')
aro_df

merged_df = amr_aro_df.merge(aro_df, how='left', on = "ARO Accession")
amr_df.index = merged_df['AMR Gene Family']
amr_df = amr_df.drop("ARO Accession", axis=1)
amr_df['AMR_gene_family'] = amr_df.index

amr_df = amr_df.groupby('AMR_gene_family').sum()
amr_df = amr_df.T
amr_df.to_csv("analysis-out/4-Select_major_ABR/gene_family_RPKM.csv")
amr_df
# Out:
# AMR_gene_family  AAC(3)    AAC(6')  AAC(6');APH(2'')  \
# Cohort
# Control             0.0  12.176266          2.217910
# Antibiotic          0.0   0.000000          0.544129
# Antibiotic          0.0   0.000000          0.241869
# Antibiotic          0.0   0.000000          0.000000
# Antibiotic          0.0   0.000000          0.295099
# ...                 ...        ...               ...
# Antibiotic          0.0   0.000000          0.000000
# Antibiotic          0.0   0.000000          0.814831
# Control             0.0  11.890071          0.000000
# Control             0.0   0.000000          0.000000
# Antibiotic          0.0   0.000000          0.000000
#
# AMR_gene_family  ABC-F ATP-binding cassette ribosomal protection protein  \
# Cohort
# Control                                                  28.968422
# Antibiotic                                               21.039744
# Antibiotic                                                3.122791
# Antibiotic                                                6.427605
# Antibiotic                                                9.895741
# ...                                                            ...
# Antibiotic                                                5.894622
# Antibiotic                                                1.435820
# Control                                                  15.280857
# Control                                                   0.000000
# Antibiotic                                                0.000000
#
# AMR_gene_family  ACC beta-lactamase  ACI beta-lactamase  ACT beta-lactamase  \
# Cohort
# Control                         0.0                 0.0            0.000000
# Antibiotic                      0.0                 0.0            4.991195
# Antibiotic                      0.0                 0.0            0.000000
# Antibiotic                      0.0                 0.0            0.000000
# Antibiotic                      0.0                 0.0            0.000000
# ...                             ...                 ...                 ...
# Antibiotic                      0.0                 0.0            0.000000
# Antibiotic                      0.0                 0.0            0.000000
# Control                         0.0                 0.0            0.000000
# Control                         0.0                 0.0            0.000000
# Antibiotic                      0.0                 0.0            0.000000
#
# AMR_gene_family  ADC beta-lactamase without carbapenemase activity  ANT(2'')  \
# Cohort
# Control                                                        0.0       0.0
# Antibiotic                                                     0.0       0.0
# Antibiotic                                                     0.0       0.0
# Antibiotic                                                     0.0       0.0
# Antibiotic                                                     0.0       0.0
# ...                                                            ...       ...
# Antibiotic                                                     0.0       0.0
# Antibiotic                                                     0.0       0.0
# Control                                                        0.0       0.0
# Control                                                        0.0       0.0
# Antibiotic                                                     0.0       0.0
#
# AMR_gene_family  ANT(3'')  ...  pmr phosphoethanolamine transferase  \
# Cohort                     ...
# Control               0.0  ...                             0.000000
# Antibiotic            0.0  ...                             1.065357
# Antibiotic            0.0  ...                             0.000000
# Antibiotic            0.0  ...                             0.000000
# Antibiotic            0.0  ...                             0.457895
# ...                   ...  ...                                  ...
# Antibiotic            0.0  ...                             1.641499
# Antibiotic            0.0  ...                             1.210895
# Control               0.0  ...                             0.000000
# Control               0.0  ...                            18.152757
# Antibiotic            0.0  ...                             0.000000
#
# AMR_gene_family  quinolone resistance protein (qnr)  \
# Cohort
# Control                                         0.0
# Antibiotic                                      0.0
# Antibiotic                                      0.0
# Antibiotic                                      0.0
# Antibiotic                                      0.0
# ...                                             ...
# Antibiotic                                      0.0
# Antibiotic                                      0.0
# Control                                         0.0
# Control                                         0.0
# Antibiotic                                      0.0
#
# AMR_gene_family  resistance-nodulation-cell division (RND) antibiotic efflux pump  \
# Cohort
# Control                                                   0.000000
# Antibiotic                                               23.112893
# Antibiotic                                                0.112935
# Antibiotic                                                1.497772
# Antibiotic                                                0.521555
# ...                                                            ...
# Antibiotic                                               47.395007
# Antibiotic                                               33.163229
# Control                                                   0.000000
# Control                                                 103.048988
# Antibiotic                                               10.203880
#
# AMR_gene_family  rifamycin-resistant beta-subunit of RNA polymerase (rpoB)  \
# Cohort
# Control                                                   0.000000
# Antibiotic                                                1.222432
# Antibiotic                                                3.269264
# Antibiotic                                                0.000000
# Antibiotic                                                0.000000
# ...                                                            ...
# Antibiotic                                                0.282011
# Antibiotic                                                0.000000
# Control                                                   0.745689
# Control                                                   0.000000
# Antibiotic                                                0.000000
#
# AMR_gene_family  small multidrug resistance (SMR) antibiotic efflux pump  \
# Cohort
# Control                                                   0.000000
# Antibiotic                                                0.000000
# Antibiotic                                                0.000000
# Antibiotic                                                0.000000
# Antibiotic                                                0.000000
# ...                                                            ...
# Antibiotic                                                0.000000
# Antibiotic                                                0.000000
# Control                                                   0.000000
# Control                                                  17.323162
# Antibiotic                                                0.000000
#
# AMR_gene_family  streptothricin acetyltransferase (SAT)  \
# Cohort
# Control                                        0.000000
# Antibiotic                                     0.000000
# Antibiotic                                     6.047105
# Antibiotic                                     0.000000
# Antibiotic                                     0.000000
# ...                                                 ...
# Antibiotic                                     0.000000
# Antibiotic                                     0.000000
# Control                                        0.000000
# Control                                        0.000000
# Antibiotic                                     0.000000
#
# AMR_gene_family  sulfonamide resistant sul  \
# Cohort
# Control                                0.0
# Antibiotic                             0.0
# Antibiotic                             0.0
# Antibiotic                             0.0
# Antibiotic                             0.0
# ...                                    ...
# Antibiotic                             0.0
# Antibiotic                             0.0
# Control                                0.0
# Control                                0.0
# Antibiotic                             0.0
#
# AMR_gene_family  tetracycline-resistant ribosomal protection protein  \
# Cohort
# Control                                                   0.000000
# Antibiotic                                                4.947627
# Antibiotic                                                0.631022
# Antibiotic                                                4.643913
# Antibiotic                                                4.966155
# ...                                                            ...
# Antibiotic                                                1.987093
# Antibiotic                                                3.687639
# Control                                                   2.760111
# Control                                                   4.832384
# Antibiotic                                                0.000000
#
# AMR_gene_family  trimethoprim resistant dihydrofolate reductase dfr  \
# Cohort
# Control                                                  25.359120
# Antibiotic                                               21.360950
# Antibiotic                                               14.228146
# Antibiotic                                               21.218998
# Antibiotic                                               18.534438
# ...                                                            ...
# Antibiotic                                                1.209445
# Antibiotic                                                8.124044
# Control                                                  14.508121
# Control                                                   0.000000
# Antibiotic                                                0.000000
#
# AMR_gene_family  undecaprenyl pyrophosphate related proteins
# Cohort
# Control                                             0.000000
# Antibiotic                                          0.000000
# Antibiotic                                          0.000000
# Antibiotic                                          0.000000
# Antibiotic                                          0.000000
# ...                                                      ...
# Antibiotic                                          4.370713
# Antibiotic                                          3.483337
# Control                                             0.000000
# Control                                             9.234440
# Antibiotic                                          0.000000
#
# [393 rows x 77 columns]

# %%
# check significance;
from scipy import stats

major_gene_families=['resistance-nodulation-cell division (RND) antibiotic efflux pump',
'major facilitator superfamily (MFS) antibiotic efflux pump',
'TEM beta-lactamase',
'ATP-binding cassette (ABC) antibiotic efflux pump',
'pmr phosphoethanolamine transferase',
'ABC-F ATP-binding cassette ribosomal protection protein',
'ampC-type beta-lactamase',
'tetracycline-resistant ribosomal protection protein',
'OKP beta-lactamase',
'ACT beta-lactamase']

amr_df_tmp = amr_df[major_gene_families]
amr_df_tmp['cohort'] = amr_df_tmp.index

control_df = amr_df_tmp[amr_df_tmp['cohort']=='Control']
ab_df = amr_df_tmp[amr_df_tmp['cohort']=='Antibiotic']
for amr in amr_df_tmp.columns:
    U, p = stats.mannwhitneyu(control_df[amr], ab_df[amr])
    if p<0.05:
        print(amr, p)
# Out:
# major facilitator superfamily (MFS) antibiotic efflux pump 0.001735435858638123
# TEM beta-lactamase 0.00014105384029800393
# ATP-binding cassette (ABC) antibiotic efflux pump 3.5726016866551654e-08
# pmr phosphoethanolamine transferase 0.0069502091615583185
# ABC-F ATP-binding cassette ribosomal protection protein 0.0054207615568021145
# ampC-type beta-lactamase 0.013392312511352986
# tetracycline-resistant ribosomal protection protein 3.6321240428597263e-06
# OKP beta-lactamase 6.089044431519622e-09
# ACT beta-lactamase 0.00021479230844706457
# cohort 1.53430539427134e-87
# <ipython-input-8-93a443081cab>:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   amr_df_tmp['cohort'] = amr_df_tmp.index

# %%
merged_df.to_csv('analysis-out/4-Select_major_ABR/gene_family_out_RPKM.csv')

# %%
major_gene_families=['resistance-nodulation-cell division (RND) antibiotic efflux pump',
'major facilitator superfamily (MFS) antibiotic efflux pump',
'ATP-binding cassette (ABC) antibiotic efflux pump',
'TEM beta-lactamase',
'ampC-type beta-lactamase',
'OKP beta-lactamase',
 'ACT beta-lactamase',                    
'pmr phosphoethanolamine transferase',
'ABC-F ATP-binding cassette ribosomal protection protein',
'tetracycline-resistant ribosomal protection protein']

# %%
amr_df.index
# Out:
# Index(['Control', 'Antibiotic', 'Antibiotic', 'Antibiotic', 'Antibiotic',
#        'Antibiotic', 'Antibiotic', 'Control', 'Antibiotic', 'Antibiotic',
#        ...
#        'Control', 'Control', 'Control', 'Antibiotic', 'Control', 'Antibiotic',
#        'Antibiotic', 'Control', 'Control', 'Antibiotic'],
#       dtype='object', name='Cohort', length=393)

# %%
#print(amr_df_tmp.columns)
#amr_df_tmp = amr_df.drop(["cohort"], axis=1)
new_df={"CPM":[], "Gene Family":[], 'Cohort':[]}
for amr in amr_df_tmp.columns:
    if amr!='cohort':
        new_df["CPM"]+=list(amr_df_tmp[amr])
        new_df['Gene Family']+=[amr for x in range(len(amr_df_tmp))]
        new_df["Cohort"]+=list(amr_df_tmp.index)
    
new_df = pd.DataFrame(new_df)
new_df
# Out:
#             CPM                                        Gene Family      Cohort
# 0      0.000000  resistance-nodulation-cell division (RND) anti...     Control
# 1     23.112893  resistance-nodulation-cell division (RND) anti...  Antibiotic
# 2      0.112935  resistance-nodulation-cell division (RND) anti...  Antibiotic
# 3      1.497772  resistance-nodulation-cell division (RND) anti...  Antibiotic
# 4      0.521555  resistance-nodulation-cell division (RND) anti...  Antibiotic
# ...         ...                                                ...         ...
# 3925   0.000000                                 ACT beta-lactamase  Antibiotic
# 3926   0.000000                                 ACT beta-lactamase  Antibiotic
# 3927   0.000000                                 ACT beta-lactamase     Control
# 3928   0.000000                                 ACT beta-lactamase     Control
# 3929   0.000000                                 ACT beta-lactamase  Antibiotic
#
# [3930 rows x 3 columns]

# %%
import seaborn as sns

sns.set_theme()
sns.set(rc={'figure.figsize':(7,11.7)})

g = sns.barplot(x = 'CPM', y = 'Gene Family', hue = 'Cohort', data = new_df,
            palette = 'hls', order=major_gene_families)
#g.set(xlim=(1, 3))
g
